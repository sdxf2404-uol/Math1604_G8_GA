# %% [markdown]
# Review for Member 1 (Harry Dalgleish - chbc0324@leeds.ac.uk). Student ID Number - 201940655

# %%
def extract_answers_sequence(file_path):
    """ 
    This function takes the input of the data, it then simplifies the data and return its in a list. 
    
    Args: 
        file_path (string): String that contains the file path for where the data is collected from 
    
    Returns: 
        list: The data in a list from the file_path 
    """
    file = open(file_path, "r")
    filelist = []
    templine = ""
    for x in file.read():
        if x == "\n":
            if templine != "":
                filelist.append(templine)
                templine = ""
        else:
            templine += x
    if templine != "":
        filelist.append(templine)
    answerslist = []
    questionoption = 0
    for line in filelist:
        if line[0] == "Q":
            if questionoption not in [0,4]:
                answerslist.append(0)
            questionoption = 0
        elif line[0] == "[":
            if line[1] == "X":
                questionoption += 1
                answerslist.append(questionoption)
            else:
                questionoption += 1
    return answerslist

# %% [markdown]
# The code above is what I wrote for extract_answers_sequence() function. It takes the file path for where the answers are being stored. It then uses that file path to open the .txt file where the data is held. It then goes through every character in the text file, separating the file into different lines and storing them in filelist. It does this by checking for "\n" a hidden line in text files which shows a new line. It then filters through filelist which has the different lines, checking for lines starting with "Q". If the line starts with Q, it knows that the line is a question. Once it does this it checks to see if the next line starts with "[". It does this checking the next character. If the next character is "]", then it skips to the next line, increasing the questionoption. It does this until the next character is an X, in which the questionoption is stored into answerslist. If there is no answer it stores a 0.

# %%
def write_answers_sequence(answers, n, destination_path):
    """ 
    This function takes the answers inputted and records it as a textfile under the name answers_list_respondent_n.txt 

    Args: 
        answers (list): List that contains the data from the corresponding respondent 
        n (integer): Number to show which respondent the data corresponds to 
        destination_path (string): String that contains the file path for where the data needs to go to 
    """
    txtfile = f"{destination_path}/answers_list_respondent_{n}.txt"
    f = open(txtfile, "x")
    for x in answers:
        f.write(f"{x}")

# %% [markdown]
# This function is write_answers_sequence(). It takes a list (answers), n which shows which respondent answered it, and the destination_path which shows where the file should end up. The code uses an f string, the destination_path and n value to store it in the variable txtfile. Before it opens this as a .txtfile and then for every answer in answerslist, writes it into the .txt file.

# %% [markdown]
# Pattern Detection

# %% [markdown]
# My first function uses pattern detection to summarise the original .txt files. Using pattern detection I noted that every question starts with Question and then the number. The following four lines then contain the answers to the question. My code checks for lines beginning with Q and also lines beginning with "[". Using the pattern of how the answers are formatted.
# Example:
# Question _____
# []
# [X]
# []
# []
#
# My code looks for the X, which marks the answer to the question.
#
# More evidence of pattern detection in my code is looking for "\n". This is something that doesn't appear in the .txt file, but does appear when you filter through the data grabbed from the file path. The "\n" represents pythons way to say a new line. I used this pattern recognition and detection to split the
